# %%
import pandas as pd
from pprint import pprint

# %%
df = pd.read_csv("politifact_claims_old.csv")

# %%
df.head()
# Out:
#    sno                                              claim  \
# 0    0  âAshley Hinson voted against the bipartisan ...
# 1    1  Chuck Grassley was âvoting to slash Medicare...
# 2    2  Ashley Hinsonâs and Mariannette Miller-Meeks...
# 3    3  Ashley Hinsonâs and Mariannette Miller-Meeks...
# 4    4  Says he worked to pass the 2018 farm bill ât...
#
#                                                  url  \
# 0  https://www.politifact.com/factchecks/2022/jan...
# 1  https://www.politifact.com/factchecks/2021/dec...
# 2  https://www.politifact.com/factchecks/2021/nov...
# 3  https://www.politifact.com/factchecks/2021/nov...
# 4  https://www.politifact.com/factchecks/2021/aug...
#
#                                        claim_entered  \
# 0  Ashley Hinson voted against the bipartisan inf...
# 1  Chuck Grassley was voting to slash Medicare wh...
# 2  Ashley Hinson voted no on the infrastructure b...
# 3  Mariannette Miller-Meeks voted no on the infra...
# ...
